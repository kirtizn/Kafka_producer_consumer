# %%
from kafka import KafkaProducer, KafkaConsumer
from json import loads
import json
import sys

### Setting up the Python consumer
bootstrap_servers = ['localhost:9092']
topicName = 'test.topic.raw'
consumer = KafkaConsumer (topicName, group_id = 'my_group_id103',bootstrap_servers = bootstrap_servers,
auto_offset_reset = 'earliest',value_deserializer=lambda x: loads(x.decode('utf-8')))  ## You can also set it as latest


# Required setting for Kafka Producer
                          
topic2 = 'topic.costly_order'
producer = KafkaProducer(bootstrap_servers = bootstrap_servers)
producer = KafkaProducer()

### Reading the message from consumer
try:
    for message in consumer:
        msg = message.value
        f = float(msg['Unit Cost'])
        print(f)
        if f > 500.0:
            print(msg)
            ack = producer.send(topic2,json.dumps(msg).encode('utf-8'))
            metadata = ack.get()
            print(metadata.topic, metadata.partition)
        
except KeyboardInterrupt:
    sys.exit()
# Out:
# 6.92
# 35.84
# 364.69
# 35.84
# 31.79
# 6.92
# 31.79
# 31.79
# 524.96
# {'Region': 'Sub-Saharan Africa', 'Country': 'Ghana', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'L', 'Order Date': '3/23/2017', 'Order ID': '601245963', 'Ship Date': '4/15/2017', 'Units Sold': '896', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '583484.16', 'Total Cost': '470364.16', 'Total Profit': '113120.00'}
# topic.costly_order 0
# 263.33
# 6.92
# 263.33
# 97.44
# 35.84
# 56.67
# 56.67
# 524.96
# {'Region': 'Sub-Saharan Africa', 'Country': 'Zimbabwe', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'C', 'Order Date': '3/28/2011', 'Order ID': '953361213', 'Ship Date': '4/8/2011', 'Units Sold': '9623', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '6266593.83', 'Total Cost': '5051690.08', 'Total Profit': '1214903.75'}
# topic.costly_order 0
# 263.33
# 263.33
# 56.67
# 524.96
# {'Region': 'Central America and the Caribbean', 'Country': 'Haiti', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'C', 'Order Date': '12/31/2010', 'Order ID': '485070693', 'Ship Date': '1/31/2011', 'Units Sold': '2052', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '1336282.92', 'Total Cost': '1077217.92', 'Total Profit': '259065.00'}
# topic.costly_order 0
# 502.54
# {'Region': 'Central America and the Caribbean', 'Country': 'Nicaragua', 'Item Type': 'Household', 'Sales Channel': 'Online', 'Order Priority': 'C', 'Order Date': '10/28/2015', 'Order ID': '573998582', 'Ship Date': '12/7/2015', 'Units Sold': '7791', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '5206491.57', 'Total Cost': '3915289.14', 'Total Profit': '1291202.43'}
# topic.costly_order 0
# 90.93
# 263.33
# 159.42
# 524.96
# {'Region': 'Asia', 'Country': 'China', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'M', 'Order Date': '2/10/2016', 'Order ID': '198927056', 'Ship Date': '3/29/2016', 'Units Sold': '5791', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '3771157.11', 'Total Cost': '3040043.36', 'Total Profit': '731113.75'}
# topic.costly_order 0
# 263.33
# 502.54
# {'Region': 'Middle East and North Africa', 'Country': 'Kuwait', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'C', 'Order Date': '6/13/2011', 'Order ID': '459386289', 'Ship Date': '7/21/2011', 'Units Sold': '1466', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '979683.82', 'Total Cost': '736723.64', 'Total Profit': '242960.18'}
# topic.costly_order 0
# 524.96
# {'Region': 'Middle East and North Africa', 'Country': 'United Arab Emirates', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'M', 'Order Date': '6/23/2012', 'Order ID': '425418365', 'Ship Date': '7/6/2012', 'Units Sold': '9603', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '6253569.63', 'Total Cost': '5041190.88', 'Total Profit': '1212378.75'}
# topic.costly_order 0
# 502.54
# {'Region': 'Europe', 'Country': 'Estonia', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'H', 'Order Date': '9/1/2011', 'Order ID': '835696351', 'Ship Date': '10/21/2011', 'Units Sold': '9976', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '6666661.52', 'Total Cost': '5013339.04', 'Total Profit': '1653322.48'}
# topic.costly_order 0
# 31.79
# 6.92
# 97.44
# 502.54
# {'Region': 'Australia and Oceania', 'Country': 'Samoa ', 'Item Type': 'Household', 'Sales Channel': 'Online', 'Order Priority': 'L', 'Order Date': '12/5/2016', 'Order ID': '937431466', 'Ship Date': '12/8/2016', 'Units Sold': '5657', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '3780403.39', 'Total Cost': '2842868.78', 'Total Profit': '937534.61'}
# topic.costly_order 0
# 97.44
# 263.33
# 56.67
# 502.54
# {'Region': 'Europe', 'Country': 'Finland', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'H', 'Order Date': '1/15/2016', 'Order ID': '757257401', 'Ship Date': '1/31/2016', 'Units Sold': '8148', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '5445063.96', 'Total Cost': '4094695.92', 'Total Profit': '1350368.04'}
# topic.costly_order 0
# 263.33
# 502.54
# {'Region': 'Central America and the Caribbean', 'Country': 'Dominica', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'C', 'Order Date': '11/19/2011', 'Order ID': '274930989', 'Ship Date': '12/13/2011', 'Units Sold': '7044', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '4707293.88', 'Total Cost': '3539891.76', 'Total Profit': '1167402.12'}
# topic.costly_order 0
# 35.84
# 35.84
# 117.11
# 31.79
# 502.54
# {'Region': 'Australia and Oceania', 'Country': 'Solomon Islands', 'Item Type': 'Household', 'Sales Channel': 'Online', 'Order Priority': 'M', 'Order Date': '12/17/2010', 'Order ID': '101328551', 'Ship Date': '12/28/2010', 'Units Sold': '4225', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '2823440.75', 'Total Cost': '2123231.50', 'Total Profit': '700209.25'}
# topic.costly_order 0
# 263.33
# 35.84
# 263.33
# 364.69
# 6.92
# 364.69
# 502.54
# {'Region': 'Asia', 'Country': 'Indonesia', 'Item Type': 'Household', 'Sales Channel': 'Online', 'Order Priority': 'C', 'Order Date': '9/28/2011', 'Order ID': '520480573', 'Ship Date': '9/28/2011', 'Units Sold': '623', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '416332.21', 'Total Cost': '313082.42', 'Total Profit': '103249.79'}
# topic.costly_order 0
# 524.96
# {'Region': 'Central America and the Caribbean', 'Country': 'Antigua and Barbuda ', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'C', 'Order Date': '10/2/2011', 'Order ID': '286891067', 'Ship Date': '10/4/2011', 'Units Sold': '6297', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '4100669.37', 'Total Cost': '3305673.12', 'Total Profit': '794996.25'}
# topic.costly_order 0
# 263.33
# 364.69
# 364.69
# 35.84
# 117.11
# 31.79
# 117.11
# 56.67
# 6.92
# 117.11
# 524.96
# {'Region': 'Europe', 'Country': 'Switzerland', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'C', 'Order Date': '7/29/2014', 'Order ID': '830410039', 'Ship Date': '8/27/2014', 'Units Sold': '5639', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '3672173.19', 'Total Cost': '2960249.44', 'Total Profit': '711923.75'}
# topic.costly_order 0
# 6.92
# 31.79
# 117.11
# 31.79
# 159.42
# 90.93
# 6.92
# 502.54
# {'Region': 'Asia', 'Country': 'Japan', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'M', 'Order Date': '7/16/2014', 'Order ID': '747796285', 'Ship Date': '7/24/2014', 'Units Sold': '8393', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '5608790.11', 'Total Cost': '4217818.22', 'Total Profit': '1390971.89'}
# topic.costly_order 0
# 31.79
# 56.67
# 35.84
# 159.42
# 6.92
# 31.79
# 35.84
# 117.11
# 6.92
# 502.54
# {'Region': 'Sub-Saharan Africa', 'Country': 'Mali', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'M', 'Order Date': '8/19/2010', 'Order ID': '363086831', 'Ship Date': '9/7/2010', 'Units Sold': '4317', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '2884921.59', 'Total Cost': '2169465.18', 'Total Profit': '715456.41'}
# topic.costly_order 0
# 56.67
# 159.42
# 6.92
# 159.42
# 524.96
# {'Region': 'Europe', 'Country': 'Italy', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'H', 'Order Date': '3/29/2011', 'Order ID': '797385394', 'Ship Date': '4/11/2011', 'Units Sold': '2913', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '1896974.73', 'Total Cost': '1529208.48', 'Total Profit': '367766.25'}
# topic.costly_order 0
# 6.92
# 6.92
# 117.11
# 364.69
# 35.84
# 56.67
# 263.33
# 31.79
# 159.42
# 364.69
# 364.69
# 117.11
# 159.42
# 263.33
# 6.92
# 117.11
# 159.42
# 97.44
# 502.54
# {'Region': 'Asia', 'Country': 'South Korea', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'C', 'Order Date': '2/27/2015', 'Order ID': '940318810', 'Ship Date': '3/6/2015', 'Units Sold': '87', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '58139.49', 'Total Cost': '43720.98', 'Total Profit': '14418.51'}
# topic.costly_order 0
# 263.33
# 90.93
# 502.54
# {'Region': 'North America', 'Country': 'Greenland', 'Item Type': 'Household', 'Sales Channel': 'Online', 'Order Priority': 'H', 'Order Date': '11/14/2010', 'Order ID': '274500548', 'Ship Date': '11/23/2010', 'Units Sold': '9667', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '6460166.09', 'Total Cost': '4858054.18', 'Total Profit': '1602111.91'}
# topic.costly_order 0
# 159.42
# 56.67
# 263.33
# 31.79
# 524.96
# {'Region': 'Europe', 'Country': 'Serbia', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'C', 'Order Date': '2/26/2014', 'Order ID': '527456033', 'Ship Date': '3/2/2014', 'Units Sold': '4816', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '3136227.36', 'Total Cost': '2528207.36', 'Total Profit': '608020.00'}
# topic.costly_order 0
# 364.69
# 35.84
# 97.44
# 117.11
# 263.33
# 263.33
# 56.67
# 90.93
# 97.44
# 97.44
# 524.96
# {'Region': 'Asia', 'Country': 'Myanmar', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'C', 'Order Date': '5/4/2012', 'Order ID': '685176360', 'Ship Date': '6/8/2012', 'Units Sold': '7766', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '5057296.86', 'Total Cost': '4076839.36', 'Total Profit': '980457.50'}
# topic.costly_order 0
# 524.96
# {'Region': 'Central America and the Caribbean', 'Country': 'The Bahamas', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'L', 'Order Date': '4/13/2017', 'Order ID': '395405519', 'Ship Date': '4/26/2017', 'Units Sold': '8135', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '5297593.35', 'Total Cost': '4270549.60', 'Total Profit': '1027043.75'}
# topic.costly_order 0
# 502.54
# {'Region': 'Sub-Saharan Africa', 'Country': 'Madagascar', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'C', 'Order Date': '1/7/2010', 'Order ID': '195241916', 'Ship Date': '2/12/2010', 'Units Sold': '5276', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '3525792.52', 'Total Cost': '2651401.04', 'Total Profit': '874391.48'}
# topic.costly_order 0
# 35.84
# 364.69
# 90.93
# 97.44
# 90.93
# 263.33
# 364.69
# 35.84
# 502.54
# {'Region': 'Middle East and North Africa', 'Country': 'Syria', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'L', 'Order Date': '8/20/2012', 'Order ID': '666964375', 'Ship Date': '10/8/2012', 'Units Sold': '8435', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '5636857.45', 'Total Cost': '4238924.90', 'Total Profit': '1397932.55'}
# topic.costly_order 0
# 364.69
# 117.11
# 524.96
# {'Region': 'Europe', 'Country': 'Armenia', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'M', 'Order Date': '1/2/2012', 'Order ID': '864479243', 'Ship Date': '2/17/2012', 'Units Sold': '7474', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '4867143.54', 'Total Cost': '3923551.04', 'Total Profit': '943592.50'}
# topic.costly_order 0
# 159.42
# 97.44
# 90.93
# 263.33
# 502.54
# {'Region': 'Asia', 'Country': 'Cambodia', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'C', 'Order Date': '4/21/2010', 'Order ID': '504370152', 'Ship Date': '6/2/2010', 'Units Sold': '3191', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '2132449.57', 'Total Cost': '1603605.14', 'Total Profit': '528844.43'}
# topic.costly_order 0
# 90.93
# 524.96
# {'Region': 'Australia and Oceania', 'Country': 'East Timor', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'C', 'Order Date': '3/23/2010', 'Order ID': '649637734', 'Ship Date': '5/10/2010', 'Units Sold': '1097', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '714377.37', 'Total Cost': '575881.12', 'Total Profit': '138496.25'}
# topic.costly_order 0
# 263.33
# 35.84
# 6.92
# 364.69
# 502.54
# {'Region': 'Sub-Saharan Africa', 'Country': 'Central African Republic', 'Item Type': 'Household', 'Sales Channel': 'Online', 'Order Priority': 'M', 'Order Date': '3/31/2015', 'Order ID': '409815204', 'Ship Date': '4/4/2015', 'Units Sold': '2281', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '1524323.87', 'Total Cost': '1146293.74', 'Total Profit': '378030.13'}
# topic.costly_order 0
# 364.69
# 502.54
# {'Region': 'Central America and the Caribbean', 'Country': 'El Salvador', 'Item Type': 'Household', 'Sales Channel': 'Online', 'Order Priority': 'M', 'Order Date': '4/28/2017', 'Order ID': '882777488', 'Ship Date': '5/21/2017', 'Units Sold': '2331', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '1557737.37', 'Total Cost': '1171420.74', 'Total Profit': '386316.63'}
# topic.costly_order 0
# 31.79
# 31.79
# 117.11
# 159.42
# 97.44
# 117.11
# 97.44
# 90.93
# 364.69
# 524.96
# {'Region': 'Asia', 'Country': 'Bhutan', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'H', 'Order Date': '9/22/2015', 'Order ID': '265624797', 'Ship Date': '10/16/2015', 'Units Sold': '3135', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '2041543.35', 'Total Cost': '1645749.60', 'Total Profit': '395793.75'}
# topic.costly_order 0
# 31.79
# 159.42
# 117.11
# 263.33
# 56.67
# 117.11
# 97.44
# 524.96
# {'Region': 'Middle East and North Africa', 'Country': 'Somalia', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'C', 'Order Date': '10/10/2011', 'Order ID': '116983211', 'Ship Date': '10/18/2011', 'Units Sold': '6786', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '4419111.06', 'Total Cost': '3562378.56', 'Total Profit': '856732.50'}
# topic.costly_order 0
# 159.42
# 97.44
# 159.42
# 56.67
# 524.96
# {'Region': 'Sub-Saharan Africa', 'Country': 'Comoros', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'C', 'Order Date': '3/28/2015', 'Order ID': '165126073', 'Ship Date': '4/8/2015', 'Units Sold': '3329', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '2167878.09', 'Total Cost': '1747591.84', 'Total Profit': '420286.25'}
# topic.costly_order 0
# 56.67
# 502.54
# {'Region': 'Asia', 'Country': 'Uzbekistan', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'H', 'Order Date': '12/25/2013', 'Order ID': '729631936', 'Ship Date': '2/11/2014', 'Units Sold': '3159', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '2111064.93', 'Total Cost': '1587523.86', 'Total Profit': '523541.07'}
# topic.costly_order 0
# 502.54
# {'Region': 'Central America and the Caribbean', 'Country': 'Antigua and Barbuda ', 'Item Type': 'Household', 'Sales Channel': 'Online', 'Order Priority': 'L', 'Order Date': '11/27/2010', 'Order ID': '668829905', 'Ship Date': '12/23/2010', 'Units Sold': '487', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '325447.49', 'Total Cost': '244736.98', 'Total Profit': '80710.51'}
# topic.costly_order 0
# 159.42
# 524.96
# {'Region': 'Australia and Oceania', 'Country': 'Tuvalu', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'M', 'Order Date': '12/12/2015', 'Order ID': '872297561', 'Ship Date': '12/20/2015', 'Units Sold': '1087', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '707865.27', 'Total Cost': '570631.52', 'Total Profit': '137233.75'}
# topic.costly_order 0
# 6.92
# 117.11
# 159.42
# 56.67
# 97.44
# 31.79
# 35.84
# 524.96
# {'Region': 'Australia and Oceania', 'Country': 'Papua New Guinea', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'C', 'Order Date': '8/17/2016', 'Order ID': '197410857', 'Ship Date': '9/29/2016', 'Units Sold': '7114', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '4632707.94', 'Total Cost': '3734565.44', 'Total Profit': '898142.50'}
# topic.costly_order 0
# 502.54
# {'Region': 'North America', 'Country': 'Greenland', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'C', 'Order Date': '7/8/2011', 'Order ID': '790940797', 'Ship Date': '8/1/2011', 'Units Sold': '5813', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '3884653.51', 'Total Cost': '2921265.02', 'Total Profit': '963388.49'}
# topic.costly_order 0
# 524.96
# {'Region': 'Europe', 'Country': 'Andorra', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'C', 'Order Date': '3/19/2016', 'Order ID': '827202975', 'Ship Date': '3/26/2016', 'Units Sold': '6598', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '4296683.58', 'Total Cost': '3463686.08', 'Total Profit': '832997.50'}
# topic.costly_order 0
# 6.92
# 159.42
# 31.79
# 97.44
# 31.79
# 56.67
# 31.79
# 524.96
# {'Region': 'Asia', 'Country': 'Bangladesh', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'L', 'Order Date': '5/9/2013', 'Order ID': '739645373', 'Ship Date': '5/15/2013', 'Units Sold': '6357', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '4139741.97', 'Total Cost': '3337170.72', 'Total Profit': '802571.25'}
# topic.costly_order 0
# 97.44
# 90.93
# 97.44
# 6.92
# 6.92
# 502.54
# {'Region': 'Europe', 'Country': 'Germany', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'H', 'Order Date': '7/6/2013', 'Order ID': '442852294', 'Ship Date': '8/21/2013', 'Units Sold': '8690', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '5807266.30', 'Total Cost': '4367072.60', 'Total Profit': '1440193.70'}
# topic.costly_order 0
# 31.79
# 35.84
# 524.96
# {'Region': 'Middle East and North Africa', 'Country': 'Egypt', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'M', 'Order Date': '9/19/2012', 'Order ID': '683694493', 'Ship Date': '10/27/2012', 'Units Sold': '9249', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '6023041.29', 'Total Cost': '4855355.04', 'Total Profit': '1167686.25'}
# topic.costly_order 0
# 56.67
# 90.93
# 31.79
# 56.67
# 524.96
# {'Region': 'Middle East and North Africa', 'Country': 'Yemen', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'M', 'Order Date': '7/4/2013', 'Order ID': '913180434', 'Ship Date': '8/13/2013', 'Units Sold': '9238', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '6015877.98', 'Total Cost': '4849580.48', 'Total Profit': '1166297.50'}
# topic.costly_order 0
# 6.92
# 263.33
# 31.79
# 90.93
# 159.42
# 56.67
# 502.54
# {'Region': 'Middle East and North Africa', 'Country': 'Israel', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'L', 'Order Date': '10/3/2013', 'Order ID': '958687436', 'Ship Date': '11/7/2013', 'Units Sold': '5771', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '3856586.17', 'Total Cost': '2900158.34', 'Total Profit': '956427.83'}
# topic.costly_order 0
# 56.67
# 35.84
# 364.69
# 31.79
# 524.96
# {'Region': 'Europe', 'Country': 'Vatican City', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'H', 'Order Date': '9/16/2012', 'Order ID': '885994422', 'Ship Date': '11/1/2012', 'Units Sold': '4293', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '2795644.53', 'Total Cost': '2253653.28', 'Total Profit': '541991.25'}
# topic.costly_order 0
# 502.54
# {'Region': 'Central America and the Caribbean', 'Country': 'Panama', 'Item Type': 'Household', 'Sales Channel': 'Online', 'Order Priority': 'C', 'Order Date': '1/21/2016', 'Order ID': '770521676', 'Ship Date': '1/31/2016', 'Units Sold': '3341', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '2232690.07', 'Total Cost': '1678986.14', 'Total Profit': '553703.93'}
# topic.costly_order 0
# 159.42
# 117.11
# 31.79
# 117.11
# 524.96
# {'Region': 'Australia and Oceania', 'Country': 'New Zealand', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'M', 'Order Date': '12/4/2011', 'Order ID': '419297778', 'Ship Date': '1/22/2012', 'Units Sold': '8385', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '5460395.85', 'Total Cost': '4401789.60', 'Total Profit': '1058606.25'}
# topic.costly_order 0
# 90.93
# 364.69
# 263.33
# 31.79
# 97.44
# 6.92
# 263.33
# 35.84
# 35.84
# 524.96
# {'Region': 'Europe', 'Country': 'Sweden', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'L', 'Order Date': '9/7/2013', 'Order ID': '573330390', 'Ship Date': '10/20/2013', 'Units Sold': '58', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '37770.18', 'Total Cost': '30447.68', 'Total Profit': '7322.50'}
# topic.costly_order 0
# 263.33
# 159.42
# 364.69
# 263.33
# 56.67
# 117.11
# 117.11
# 97.44
# 524.96
# {'Region': 'Europe', 'Country': 'Romania', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'L', 'Order Date': '4/20/2015', 'Order ID': '530370843', 'Ship Date': '5/26/2015', 'Units Sold': '7373', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '4801371.33', 'Total Cost': '3870530.08', 'Total Profit': '930841.25'}
# topic.costly_order 0
# 263.33
# 97.44
# 56.67
# 117.11
# 90.93
# 31.79
# 56.67
# 35.84
# 159.42
# 502.54
# {'Region': 'Sub-Saharan Africa', 'Country': 'Zambia', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'H', 'Order Date': '8/5/2010', 'Order ID': '262171399', 'Ship Date': '8/9/2010', 'Units Sold': '1198', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '800587.46', 'Total Cost': '602042.92', 'Total Profit': '198544.54'}
# topic.costly_order 0
# 263.33
# 56.67
# 6.92
# 263.33
# 524.96
# {'Region': 'Australia and Oceania', 'Country': 'Palau', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'H', 'Order Date': '11/6/2014', 'Order ID': '211121451', 'Ship Date': '12/20/2014', 'Units Sold': '4384', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '2854904.64', 'Total Cost': '2301424.64', 'Total Profit': '553480.00'}
# topic.costly_order 0
# 97.44
# 90.93
# 502.54
# {'Region': 'Sub-Saharan Africa', 'Country': 'Seychelles ', 'Item Type': 'Household', 'Sales Channel': 'Online', 'Order Priority': 'C', 'Order Date': '2/28/2012', 'Order ID': '958708035', 'Ship Date': '3/29/2012', 'Units Sold': '1867', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '1247660.09', 'Total Cost': '938242.18', 'Total Profit': '309417.91'}
# topic.costly_order 0
# 56.67
# 502.54
# {'Region': 'Sub-Saharan Africa', 'Country': 'Mauritania', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'L', 'Order Date': '8/29/2010', 'Order ID': '598055207', 'Ship Date': '10/7/2010', 'Units Sold': '6681', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '4464711.87', 'Total Cost': '3357469.74', 'Total Profit': '1107242.13'}
# topic.costly_order 0
# 364.69
# 524.96
# {'Region': 'Europe', 'Country': 'Ireland', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'M', 'Order Date': '8/10/2015', 'Order ID': '694268834', 'Ship Date': '8/23/2015', 'Units Sold': '8431', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '5490351.51', 'Total Cost': '4425937.76', 'Total Profit': '1064413.75'}
# topic.costly_order 0
# 159.42
# 90.93
# 31.79
# 502.54
# {'Region': 'Sub-Saharan Africa', 'Country': 'Malawi', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'H', 'Order Date': '4/24/2012', 'Order ID': '358857953', 'Ship Date': '5/14/2012', 'Units Sold': '2898', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '1936646.46', 'Total Cost': '1456360.92', 'Total Profit': '480285.54'}
# topic.costly_order 0
# 35.84
# 263.33
# 97.44
# 56.67
# 263.33
# 6.92
# 364.69
# 90.93
# 90.93
# 35.84
# 117.11
# 6.92
# 56.67
# 117.11
# 35.84
# 364.69
# 117.11
# 90.93
# 31.79
# 6.92
# 117.11
# 35.84
# 56.67
# 97.44
# 97.44
# 364.69
# 117.11
# 90.93
# 524.96
# {'Region': 'Asia', 'Country': 'Kyrgyzstan', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'M', 'Order Date': '12/28/2015', 'Order ID': '792205512', 'Ship Date': '1/30/2016', 'Units Sold': '70', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '45584.70', 'Total Cost': '36747.20', 'Total Profit': '8837.50'}
# topic.costly_order 0
# 97.44
# 56.67
# 117.11
# 263.33
# 117.11
# 90.93
# 90.93
# 6.92
# 6.92
# 56.67
# 263.33
# 31.79
# 35.84
# 364.69
# 97.44
# 524.96
# {'Region': 'Europe', 'Country': 'Greece', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'L', 'Order Date': '3/1/2016', 'Order ID': '764307105', 'Ship Date': '4/1/2016', 'Units Sold': '4312', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '2808017.52', 'Total Cost': '2263627.52', 'Total Profit': '544390.00'}
# topic.costly_order 0
# 35.84
# 90.93
# 56.67
# 31.79
# 90.93
# 90.93
# 502.54
# {'Region': 'Middle East and North Africa', 'Country': 'Saudi Arabia', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'H', 'Order Date': '5/4/2017', 'Order ID': '311968648', 'Ship Date': '6/10/2017', 'Units Sold': '7310', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '4885053.70', 'Total Cost': '3673567.40', 'Total Profit': '1211486.30'}
# topic.costly_order 0
# 56.67
# 31.79
# 56.67
# 6.92
# 35.84
# 56.67
# 524.96
# {'Region': 'Sub-Saharan Africa', 'Country': 'Seychelles ', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'L', 'Order Date': '4/26/2015', 'Order ID': '113373172', 'Ship Date': '6/14/2015', 'Units Sold': '8496', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '5532680.16', 'Total Cost': '4460060.16', 'Total Profit': '1072620.00'}
# topic.costly_order 0
# 56.67
# 56.67
# 502.54
# {'Region': 'Sub-Saharan Africa', 'Country': 'Benin', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'H', 'Order Date': '11/1/2011', 'Order ID': '496790444', 'Ship Date': '11/3/2011', 'Units Sold': '187', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '124966.49', 'Total Cost': '93974.98', 'Total Profit': '30991.51'}
# topic.costly_order 0
# 117.11
# 31.79
# 90.93
# 6.92
# 502.54
# {'Region': 'Asia', 'Country': 'Brunei', 'Item Type': 'Household', 'Sales Channel': 'Online', 'Order Priority': 'H', 'Order Date': '12/16/2014', 'Order ID': '934604632', 'Ship Date': '2/1/2015', 'Units Sold': '9135', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '6104646.45', 'Total Cost': '4590702.90', 'Total Profit': '1513943.55'}
# topic.costly_order 0
# 90.93
# 263.33
# 502.54
# {'Region': 'Sub-Saharan Africa', 'Country': 'Senegal', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'L', 'Order Date': '9/22/2016', 'Order ID': '682462823', 'Ship Date': '9/22/2016', 'Units Sold': '4770', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '3187647.90', 'Total Cost': '2397115.80', 'Total Profit': '790532.10'}
# topic.costly_order 0
# 364.69
# 6.92
# 90.93
# 159.42
# 97.44
# 502.54
# {'Region': 'Central America and the Caribbean', 'Country': 'Cuba', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'L', 'Order Date': '5/14/2011', 'Order ID': '357682073', 'Ship Date': '6/10/2011', 'Units Sold': '4929', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '3293902.83', 'Total Cost': '2477019.66', 'Total Profit': '816883.17'}
# topic.costly_order 0
# 159.42
# 502.54
# {'Region': 'Sub-Saharan Africa', 'Country': 'Democratic Republic of the Congo', 'Item Type': 'Household', 'Sales Channel': 'Online', 'Order Priority': 'C', 'Order Date': '4/8/2010', 'Order ID': '415498483', 'Ship Date': '5/1/2010', 'Units Sold': '4089', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '2732556.03', 'Total Cost': '2054886.06', 'Total Profit': '677669.97'}
# topic.costly_order 0
# 35.84
# 159.42
# 364.69
# 502.54
# {'Region': 'Sub-Saharan Africa', 'Country': 'Madagascar', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'M', 'Order Date': '6/3/2011', 'Order ID': '407590043', 'Ship Date': '6/10/2011', 'Units Sold': '3806', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '2543435.62', 'Total Cost': '1912667.24', 'Total Profit': '630768.38'}
# topic.costly_order 0
# 364.69
# 524.96
# {'Region': 'Central America and the Caribbean', 'Country': 'Cuba', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'L', 'Order Date': '6/28/2013', 'Order ID': '405146443', 'Ship Date': '8/2/2013', 'Units Sold': '691', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '449986.11', 'Total Cost': '362747.36', 'Total Profit': '87238.75'}
# topic.costly_order 0
# 31.79
# 524.96
# {'Region': 'Europe', 'Country': 'Switzerland', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'M', 'Order Date': '1/25/2017', 'Order ID': '820897424', 'Ship Date': '2/28/2017', 'Units Sold': '645', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '420030.45', 'Total Cost': '338599.20', 'Total Profit': '81431.25'}
# topic.costly_order 0
# 524.96
# {'Region': 'Central America and the Caribbean', 'Country': 'Antigua and Barbuda ', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'L', 'Order Date': '8/29/2016', 'Order ID': '596069514', 'Ship Date': '9/6/2016', 'Units Sold': '9070', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '5906474.70', 'Total Cost': '4761387.20', 'Total Profit': '1145087.50'}
# topic.costly_order 0
# 159.42
# 56.67
# 159.42
# 56.67
# 263.33
# 56.67
# 35.84
# 90.93
# 159.42
# 90.93
# 35.84
# 97.44
# 35.84
# 97.44
# 6.92
# 6.92
# 56.67
# 364.69
# 56.67
# 97.44
# 31.79
# 524.96
# {'Region': 'Middle East and North Africa', 'Country': 'Tunisia ', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'L', 'Order Date': '4/11/2015', 'Order ID': '322244727', 'Ship Date': '5/13/2015', 'Units Sold': '8231', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '5360109.51', 'Total Cost': '4320945.76', 'Total Profit': '1039163.75'}
# topic.costly_order 0
# 31.79
# 31.79
# 35.84
# 97.44
# 90.93
# 364.69
# 524.96
# {'Region': 'Sub-Saharan Africa', 'Country': 'Cameroon', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'M', 'Order Date': '5/1/2017', 'Order ID': '456136739', 'Ship Date': '6/10/2017', 'Units Sold': '9852', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '6415720.92', 'Total Cost': '5171905.92', 'Total Profit': '1243815.00'}
# topic.costly_order 0
# 159.42
# 6.92
# 159.42
# 117.11
# 117.11
# 35.84
# 56.67
# 31.79
# 524.96
# {'Region': 'Sub-Saharan Africa', 'Country': 'Swaziland', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'C', 'Order Date': '8/27/2014', 'Order ID': '579111945', 'Ship Date': '9/29/2014', 'Units Sold': '949', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '617998.29', 'Total Cost': '498187.04', 'Total Profit': '119811.25'}
# topic.costly_order 0
# 117.11
# 524.96
# {'Region': 'Europe', 'Country': 'Kosovo', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'M', 'Order Date': '11/12/2011', 'Order ID': '818779551', 'Ship Date': '12/1/2011', 'Units Sold': '3919', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '2552091.99', 'Total Cost': '2057318.24', 'Total Profit': '494773.75'}
# topic.costly_order 0
# 90.93
# 117.11
# 364.69
# 35.84
# 90.93
# 90.93
# 6.92
# 35.84
# 90.93
# 524.96
# {'Region': 'Australia and Oceania', 'Country': 'East Timor', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'L', 'Order Date': '9/30/2010', 'Order ID': '986325347', 'Ship Date': '10/29/2010', 'Units Sold': '4443', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '2893326.03', 'Total Cost': '2332397.28', 'Total Profit': '560928.75'}
# topic.costly_order 0
# 364.69
# 35.84
# 90.93
# 56.67
# 524.96
# {'Region': 'Sub-Saharan Africa', 'Country': 'Seychelles ', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'H', 'Order Date': '11/14/2011', 'Order ID': '884861886', 'Ship Date': '12/5/2011', 'Units Sold': '9151', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '5959222.71', 'Total Cost': '4803908.96', 'Total Profit': '1155313.75'}
# topic.costly_order 0
# 97.44
# 35.84
# 159.42
# 6.92
# 90.93
# 502.54
# {'Region': 'Central America and the Caribbean', 'Country': 'Barbados', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'L', 'Order Date': '9/19/2013', 'Order ID': '464939534', 'Ship Date': '9/20/2013', 'Units Sold': '4795', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '3204354.65', 'Total Cost': '2409679.30', 'Total Profit': '794675.35'}
# topic.costly_order 0
# 31.79
# 90.93
# 524.96
# {'Region': 'Europe', 'Country': 'Netherlands', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'H', 'Order Date': '3/10/2014', 'Order ID': '718264949', 'Ship Date': '3/24/2014', 'Units Sold': '9415', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '6131142.15', 'Total Cost': '4942498.40', 'Total Profit': '1188643.75'}
# topic.costly_order 0
# 524.96
# {'Region': 'Europe', 'Country': 'Croatia', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'H', 'Order Date': '9/13/2015', 'Order ID': '498229825', 'Ship Date': '10/6/2015', 'Units Sold': '6132', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '3993219.72', 'Total Cost': '3219054.72', 'Total Profit': '774165.00'}
# topic.costly_order 0
# 364.69
# 35.84
# 90.93
# 117.11
# 159.42
# 35.84
# 6.92
# 159.42
# 502.54
# {'Region': 'Central America and the Caribbean', 'Country': 'Haiti', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'L', 'Order Date': '11/15/2014', 'Order ID': '918110549', 'Ship Date': '11/21/2014', 'Units Sold': '8169', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '5459097.63', 'Total Cost': '4105249.26', 'Total Profit': '1353848.37'}
# topic.costly_order 0
# 56.67
# 524.96
# {'Region': 'Sub-Saharan Africa', 'Country': 'The Gambia', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'H', 'Order Date': '7/8/2014', 'Order ID': '402468097', 'Ship Date': '8/27/2014', 'Units Sold': '8108', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '5280010.68', 'Total Cost': '4256375.68', 'Total Profit': '1023635.00'}
# topic.costly_order 0
# 90.93
# 502.54
# {'Region': 'Europe', 'Country': 'Latvia', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'C', 'Order Date': '7/5/2010', 'Order ID': '345449912', 'Ship Date': '7/12/2010', 'Units Sold': '5160', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '3448273.20', 'Total Cost': '2593106.40', 'Total Profit': '855166.80'}
# topic.costly_order 0
# 364.69
# 117.11
# 6.92
# 6.92
# 56.67
# 524.96
# {'Region': 'Sub-Saharan Africa', 'Country': 'Mauritania', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'H', 'Order Date': '6/8/2015', 'Order ID': '767547214', 'Ship Date': '7/2/2015', 'Units Sold': '3132', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '2039589.72', 'Total Cost': '1644174.72', 'Total Profit': '395415.00'}
# topic.costly_order 0
# 263.33
# 56.67
# 6.92
# 56.67
# 117.11
# 159.42
# 364.69
# 159.42
# 6.92
# 56.67
# 35.84
# 502.54
# {'Region': 'Sub-Saharan Africa', 'Country': 'Liberia', 'Item Type': 'Household', 'Sales Channel': 'Online', 'Order Priority': 'H', 'Order Date': '3/28/2011', 'Order ID': '941081416', 'Ship Date': '4/12/2011', 'Units Sold': '5759', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '3848566.93', 'Total Cost': '2894127.86', 'Total Profit': '954439.07'}
# topic.costly_order 0
# 159.42
# 502.54
# {'Region': 'Central America and the Caribbean', 'Country': 'Costa Rica', 'Item Type': 'Household', 'Sales Channel': 'Online', 'Order Priority': 'H', 'Order Date': '2/23/2013', 'Order ID': '235540282', 'Ship Date': '4/1/2013', 'Units Sold': '459', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '306735.93', 'Total Cost': '230665.86', 'Total Profit': '76070.07'}
# topic.costly_order 0
# 117.11
# 31.79
# 364.69
# 524.96
# {'Region': 'Asia', 'Country': 'Singapore', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'C', 'Order Date': '7/27/2010', 'Order ID': '376112067', 'Ship Date': '9/9/2010', 'Units Sold': '8774', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '5713716.54', 'Total Cost': '4605999.04', 'Total Profit': '1107717.50'}
# topic.costly_order 0
# 35.84
# 31.79
# 31.79
# 159.42
# 159.42
# 31.79
# 56.67
# 35.84
# 159.42
# 263.33
# 56.67
# 35.84
# 117.11
# 97.44
# 263.33
# 524.96
# {'Region': 'Asia', 'Country': 'Malaysia', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'M', 'Order Date': '9/20/2016', 'Order ID': '917744910', 'Ship Date': '11/6/2016', 'Units Sold': '9968', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '6491261.28', 'Total Cost': '5232801.28', 'Total Profit': '1258460.00'}
# topic.costly_order 0
# 90.93
# 263.33
# 502.54
# {'Region': 'Asia', 'Country': 'Brunei', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'M', 'Order Date': '10/5/2012', 'Order ID': '431017529', 'Ship Date': '10/25/2012', 'Units Sold': '6520', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '4357120.40', 'Total Cost': '3276560.80', 'Total Profit': '1080559.60'}
# topic.costly_order 0
# 35.84
# 117.11
# 90.93
# 263.33
# 117.11
# 524.96
# {'Region': 'Central America and the Caribbean', 'Country': 'Haiti', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'H', 'Order Date': '4/17/2013', 'Order ID': '648686730', 'Ship Date': '5/2/2013', 'Units Sold': '9674', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '6299805.54', 'Total Cost': '5078463.04', 'Total Profit': '1221342.50'}
# topic.costly_order 0
# 502.54
# {'Region': 'Europe', 'Country': 'Lithuania', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'H', 'Order Date': '3/10/2012', 'Order ID': '671710383', 'Ship Date': '4/28/2012', 'Units Sold': '2884', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '1927290.68', 'Total Cost': '1449325.36', 'Total Profit': '477965.32'}
# topic.costly_order 0
# 31.79
# 56.67
# 502.54
# {'Region': 'Middle East and North Africa', 'Country': 'Tunisia ', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'C', 'Order Date': '6/6/2011', 'Order ID': '365241181', 'Ship Date': '6/27/2011', 'Units Sold': '1837', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '1227611.99', 'Total Cost': '923165.98', 'Total Profit': '304446.01'}
# topic.costly_order 0
# 6.92
# 6.92
# 56.67
# 159.42
# 524.96
# {'Region': 'Sub-Saharan Africa', 'Country': 'Sudan', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'M', 'Order Date': '7/5/2013', 'Order ID': '443088328', 'Ship Date': '8/21/2013', 'Units Sold': '8538', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '5560030.98', 'Total Cost': '4482108.48', 'Total Profit': '1077922.50'}
# topic.costly_order 0
# 263.33
# 263.33
# 502.54
# {'Region': 'Europe', 'Country': 'Armenia', 'Item Type': 'Household', 'Sales Channel': 'Online', 'Order Priority': 'M', 'Order Date': '3/25/2016', 'Order ID': '133872544', 'Ship Date': '4/6/2016', 'Units Sold': '4716', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '3151561.32', 'Total Cost': '2369978.64', 'Total Profit': '781582.68'}
# topic.costly_order 0
# 6.92
# 117.11
# 502.54
# {'Region': 'Europe', 'Country': 'Andorra', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'C', 'Order Date': '5/25/2012', 'Order ID': '711981284', 'Ship Date': '6/16/2012', 'Units Sold': '9939', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '6641935.53', 'Total Cost': '4994745.06', 'Total Profit': '1647190.47'}
# topic.costly_order 0
# 31.79
# 117.11
# 263.33
# 263.33
# 97.44
# 117.11
# 56.67
# 159.42
# 35.84
# 364.69
# 56.67
# 90.93
# 31.79
# 56.67
# 90.93
# 90.93
# 524.96
# {'Region': 'Asia', 'Country': 'North Korea', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'H', 'Order Date': '7/15/2014', 'Order ID': '725165307', 'Ship Date': '7/31/2014', 'Units Sold': '1384', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '901274.64', 'Total Cost': '726544.64', 'Total Profit': '174730.00'}
# topic.costly_order 0
# 364.69
# 263.33
# 524.96
# {'Region': 'Asia', 'Country': 'Indonesia', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'M', 'Order Date': '2/18/2016', 'Order ID': '211837279', 'Ship Date': '3/6/2016', 'Units Sold': '6213', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '4045967.73', 'Total Cost': '3261576.48', 'Total Profit': '784391.25'}
# topic.costly_order 0
# 56.67
# 524.96
# {'Region': 'Sub-Saharan Africa', 'Country': 'Nigeria', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'M', 'Order Date': '6/6/2013', 'Order ID': '307693850', 'Ship Date': '7/22/2013', 'Units Sold': '2303', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '1499736.63', 'Total Cost': '1208982.88', 'Total Profit': '290753.75'}
# topic.costly_order 0
# 6.92
# 56.67
# 56.67
# 502.54
# {'Region': 'Central America and the Caribbean', 'Country': 'Costa Rica', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'C', 'Order Date': '10/9/2011', 'Order ID': '233482921', 'Ship Date': '10/28/2011', 'Units Sold': '1640', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '1095962.80', 'Total Cost': '824165.60', 'Total Profit': '271797.20'}
# topic.costly_order 0
# 35.84
# 263.33
# 502.54
# {'Region': 'Europe', 'Country': 'Ireland', 'Item Type': 'Household', 'Sales Channel': 'Online', 'Order Priority': 'M', 'Order Date': '9/5/2014', 'Order ID': '307030808', 'Ship Date': '10/22/2014', 'Units Sold': '6094', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '4072437.38', 'Total Cost': '3062478.76', 'Total Profit': '1009958.62'}
# topic.costly_order 0
# 90.93
# 31.79
# 90.93
# 159.42
# 35.84
# 159.42
# 90.93
# 31.79
# 263.33
# 6.92
# 90.93
# 364.69
# 502.54
# {'Region': 'Europe', 'Country': 'Latvia', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'C', 'Order Date': '6/22/2010', 'Order ID': '281609904', 'Ship Date': '7/23/2010', 'Units Sold': '3484', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '2328252.68', 'Total Cost': '1750849.36', 'Total Profit': '577403.32'}
# topic.costly_order 0
# 35.84
# 502.54
# {'Region': 'Europe', 'Country': 'Macedonia', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'L', 'Order Date': '4/23/2016', 'Order ID': '651630294', 'Ship Date': '5/3/2016', 'Units Sold': '739', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '493851.53', 'Total Cost': '371377.06', 'Total Profit': '122474.47'}
# topic.costly_order 0
# 159.42
# 56.67
# 97.44
# 524.96
# {'Region': 'Asia', 'Country': 'Turkmenistan', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'C', 'Order Date': '8/27/2013', 'Order ID': '369887626', 'Ship Date': '9/8/2013', 'Units Sold': '6823', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '4443205.83', 'Total Cost': '3581802.08', 'Total Profit': '861403.75'}
# topic.costly_order 0
# 502.54
# {'Region': 'Middle East and North Africa', 'Country': 'Turkey', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'M', 'Order Date': '11/25/2015', 'Order ID': '759456384', 'Ship Date': '12/19/2015', 'Units Sold': '8876', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '5931564.52', 'Total Cost': '4460545.04', 'Total Profit': '1471019.48'}
# topic.costly_order 0
# 117.11
# 502.54
# {'Region': 'Sub-Saharan Africa', 'Country': 'Seychelles ', 'Item Type': 'Household', 'Sales Channel': 'Online', 'Order Priority': 'C', 'Order Date': '1/21/2010', 'Order ID': '990472257', 'Ship Date': '3/6/2010', 'Units Sold': '1606', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '1073241.62', 'Total Cost': '807079.24', 'Total Profit': '266162.38'}
# topic.costly_order 0
# 31.79
# 35.84
# 90.93
# 56.67
# 90.93
# 524.96
# {'Region': 'Europe', 'Country': 'Greece', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'H', 'Order Date': '4/25/2015', 'Order ID': '198937356', 'Ship Date': '6/10/2015', 'Units Sold': '8839', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '5756045.19', 'Total Cost': '4640121.44', 'Total Profit': '1115923.75'}
# topic.costly_order 0
# 502.54
# {'Region': 'North America', 'Country': 'Greenland', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'M', 'Order Date': '12/8/2013', 'Order ID': '431690013', 'Ship Date': '1/2/2014', 'Units Sold': '5523', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '3690855.21', 'Total Cost': '2775528.42', 'Total Profit': '915326.79'}
# topic.costly_order 0
# 56.67
# 31.79
# 31.79
# 6.92
# 117.11
# 97.44
# 524.96
# {'Region': 'Sub-Saharan Africa', 'Country': 'Tanzania', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'L', 'Order Date': '8/16/2016', 'Order ID': '760781610', 'Ship Date': '9/15/2016', 'Units Sold': '1039', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '676607.19', 'Total Cost': '545433.44', 'Total Profit': '131173.75'}
# topic.costly_order 0
# 6.92
# 263.33
# 6.92
# 6.92
# 159.42
# 263.33
# 364.69
# 364.69
# 502.54
# {'Region': 'Australia and Oceania', 'Country': 'Tuvalu', 'Item Type': 'Household', 'Sales Channel': 'Online', 'Order Priority': 'M', 'Order Date': '8/4/2014', 'Order ID': '683723247', 'Ship Date': '8/5/2014', 'Units Sold': '7757', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '5183770.39', 'Total Cost': '3898202.78', 'Total Profit': '1285567.61'}
# topic.costly_order 0
# 6.92
# 97.44
# 524.96
# {'Region': 'Europe', 'Country': 'Russia', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'M', 'Order Date': '6/20/2014', 'Order ID': '262666642', 'Ship Date': '7/14/2014', 'Units Sold': '7751', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '5047528.71', 'Total Cost': '4068964.96', 'Total Profit': '978563.75'}
# topic.costly_order 0
# 524.96
# {'Region': 'Australia and Oceania', 'Country': 'Solomon Islands', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'L', 'Order Date': '8/5/2011', 'Order ID': '411099231', 'Ship Date': '8/26/2011', 'Units Sold': '2253', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '1467176.13', 'Total Cost': '1182734.88', 'Total Profit': '284441.25'}
# topic.costly_order 0
# 502.54
# {'Region': 'Europe', 'Country': 'Moldova ', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'L', 'Order Date': '7/26/2012', 'Order ID': '776141011', 'Ship Date': '8/11/2012', 'Units Sold': '6228', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '4161985.56', 'Total Cost': '3129819.12', 'Total Profit': '1032166.44'}
# topic.costly_order 0
# 90.93
# 6.92
# 364.69
# 364.69
# 90.93
# 6.92
# 117.11
# 263.33
# 31.79
# 56.67
# 364.69
# 35.84
# 524.96
# {'Region': 'Middle East and North Africa', 'Country': 'United Arab Emirates', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'C', 'Order Date': '2/25/2016', 'Order ID': '813149917', 'Ship Date': '3/12/2016', 'Units Sold': '7985', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '5199911.85', 'Total Cost': '4191805.60', 'Total Profit': '1008106.25'}
# topic.costly_order 0
# 364.69
# 31.79
# 364.69
# 117.11
# 263.33
# 56.67
# 502.54
# {'Region': 'Sub-Saharan Africa', 'Country': 'Rwanda', 'Item Type': 'Household', 'Sales Channel': 'Online', 'Order Priority': 'C', 'Order Date': '1/2/2016', 'Order ID': '101039731', 'Ship Date': '2/8/2016', 'Units Sold': '8757', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '5852040.39', 'Total Cost': '4400742.78', 'Total Profit': '1451297.61'}
# topic.costly_order 0
# 159.42
# 31.79
# 502.54
# {'Region': 'Europe', 'Country': 'Andorra', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'M', 'Order Date': '2/11/2013', 'Order ID': '146668612', 'Ship Date': '3/1/2013', 'Units Sold': '1357', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '906842.39', 'Total Cost': '681946.78', 'Total Profit': '224895.61'}
# topic.costly_order 0
# 524.96
# {'Region': 'Europe', 'Country': 'Hungary', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'H', 'Order Date': '11/16/2014', 'Order ID': '568729436', 'Ship Date': '1/4/2015', 'Units Sold': '8533', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '5556774.93', 'Total Cost': '4479483.68', 'Total Profit': '1077291.25'}
# topic.costly_order 0
# 364.69
# 35.84
# 524.96
# ...
# topic.costly_order 0
# 263.33
# 364.69
# 524.96
# {'Region': 'Europe', 'Country': 'Bosnia and Herzegovina', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'M', 'Order Date': '4/10/2010', 'Order ID': '556557786', 'Ship Date': '5/6/2010', 'Units Sold': '6672', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '4344873.12', 'Total Cost': '3502533.12', 'Total Profit': '842340.00'}
# topic.costly_order 0
# 35.84
# 524.96
# {'Region': 'Europe', 'Country': 'Germany', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'L', 'Order Date': '3/2/2013', 'Order ID': '710120046', 'Ship Date': '3/4/2013', 'Units Sold': '9157', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '5963129.97', 'Total Cost': '4807058.72', 'Total Profit': '1156071.25'}
# topic.costly_order 0
# 117.11
# 364.69
# 90.93
# 159.42
# 159.42
# 502.54
# {'Region': 'Europe', 'Country': 'Moldova ', 'Item Type': 'Household', 'Sales Channel': 'Online', 'Order Priority': 'H', 'Order Date': '3/14/2010', 'Order ID': '262786805', 'Ship Date': '4/11/2010', 'Units Sold': '3310', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '2211973.70', 'Total Cost': '1663407.40', 'Total Profit': '548566.30'}
# topic.costly_order 0
# 524.96
# {'Region': 'Australia and Oceania', 'Country': 'Solomon Islands', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'L', 'Order Date': '12/22/2014', 'Order ID': '721363437', 'Ship Date': '1/7/2015', 'Units Sold': '6326', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '4119554.46', 'Total Cost': '3320896.96', 'Total Profit': '798657.50'}
# topic.costly_order 0
# 6.92
# 364.69
# 117.11
# 117.11
# 6.92
# 502.54
# {'Region': 'Sub-Saharan Africa', 'Country': 'Ghana', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'H', 'Order Date': '1/1/2015', 'Order ID': '696372115', 'Ship Date': '1/24/2015', 'Units Sold': '839', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '560678.53', 'Total Cost': '421631.06', 'Total Profit': '139047.47'}
# topic.costly_order 0
# 97.44
# 56.67
# 524.96
# {'Region': 'Middle East and North Africa', 'Country': 'Turkey', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'M', 'Order Date': '4/23/2010', 'Order ID': '638935506', 'Ship Date': '6/8/2010', 'Units Sold': '4070', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '2650424.70', 'Total Cost': '2136587.20', 'Total Profit': '513837.50'}
# topic.costly_order 0
# 97.44
# 90.93
# 6.92
# 35.84
# 6.92
# 502.54
# {'Region': 'Sub-Saharan Africa', 'Country': 'Mauritania', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'H', 'Order Date': '10/22/2014', 'Order ID': '679834687', 'Ship Date': '11/6/2014', 'Units Sold': '7046', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '4708630.42', 'Total Cost': '3540896.84', 'Total Profit': '1167733.58'}
# topic.costly_order 0
# 263.33
# 502.54
# {'Region': 'Asia', 'Country': 'Taiwan', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'H', 'Order Date': '1/28/2010', 'Order ID': '627513158', 'Ship Date': '2/11/2010', 'Units Sold': '3943', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '2634988.61', 'Total Cost': '1981515.22', 'Total Profit': '653473.39'}
# topic.costly_order 0
# 117.11
# 117.11
# 502.54
# {'Region': 'Sub-Saharan Africa', 'Country': 'South Africa', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'H', 'Order Date': '3/18/2014', 'Order ID': '812174022', 'Ship Date': '4/19/2014', 'Units Sold': '9196', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '6145410.92', 'Total Cost': '4621357.84', 'Total Profit': '1524053.08'}
# topic.costly_order 0
# 6.92
# 364.69
# 31.79
# 31.79
# 35.84
# 97.44
# 263.33
# 117.11
# 524.96
# {'Region': 'Europe', 'Country': 'Cyprus', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'H', 'Order Date': '5/3/2011', 'Order ID': '823404538', 'Ship Date': '5/27/2011', 'Units Sold': '2556', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '1664492.76', 'Total Cost': '1341797.76', 'Total Profit': '322695.00'}
# topic.costly_order 0
# 263.33
# 6.92
# 524.96
# {'Region': 'Australia and Oceania', 'Country': 'Federated States of Micronesia', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'C', 'Order Date': '2/27/2013', 'Order ID': '538125216', 'Ship Date': '4/3/2013', 'Units Sold': '2065', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '1344748.65', 'Total Cost': '1084042.40', 'Total Profit': '260706.25'}
# topic.costly_order 0
# 524.96
# {'Region': 'Australia and Oceania', 'Country': 'Australia', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'M', 'Order Date': '11/21/2013', 'Order ID': '878008306', 'Ship Date': '11/24/2013', 'Units Sold': '1024', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '666839.04', 'Total Cost': '537559.04', 'Total Profit': '129280.00'}
# topic.costly_order 0
# 97.44
# 6.92
# 6.92
# 159.42
# 117.11
# 364.69
# 56.67
# 524.96
# {'Region': 'Europe', 'Country': 'Greece', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'M', 'Order Date': '2/24/2014', 'Order ID': '689925801', 'Ship Date': '2/24/2014', 'Units Sold': '3231', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '2104059.51', 'Total Cost': '1696145.76', 'Total Profit': '407913.75'}
# topic.costly_order 0
# 159.42
# 263.33
# 97.44
# 97.44
# 97.44
# 524.96
# {'Region': 'Middle East and North Africa', 'Country': 'Bahrain', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'L', 'Order Date': '10/2/2012', 'Order ID': '132289826', 'Ship Date': '10/22/2012', 'Units Sold': '6354', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '4137788.34', 'Total Cost': '3335595.84', 'Total Profit': '802192.50'}
# topic.costly_order 0
# 263.33
# 364.69
# 97.44
# 364.69
# 35.84
# 56.67
# 6.92
# 502.54
# {'Region': 'Central America and the Caribbean', 'Country': 'Honduras', 'Item Type': 'Household', 'Sales Channel': 'Online', 'Order Priority': 'L', 'Order Date': '9/5/2013', 'Order ID': '382561814', 'Ship Date': '10/6/2013', 'Units Sold': '7397', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '4943193.19', 'Total Cost': '3717288.38', 'Total Profit': '1225904.81'}
# topic.costly_order 0
# 97.44
# 524.96
# {'Region': 'Central America and the Caribbean', 'Country': 'Cuba', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'M', 'Order Date': '4/10/2013', 'Order ID': '812100636', 'Ship Date': '4/22/2013', 'Units Sold': '7480', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '4871050.80', 'Total Cost': '3926700.80', 'Total Profit': '944350.00'}
# topic.costly_order 0
# 90.93
# 263.33
# 56.67
# 117.11
# 263.33
# 117.11
# 90.93
# 31.79
# 117.11
# 97.44
# 263.33
# 159.42
# 6.92
# 524.96
# {'Region': 'Australia and Oceania', 'Country': 'East Timor', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'L', 'Order Date': '8/9/2014', 'Order ID': '312695634', 'Ship Date': '9/28/2014', 'Units Sold': '2442', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '1590254.82', 'Total Cost': '1281952.32', 'Total Profit': '308302.50'}
# topic.costly_order 0
# 524.96
# {'Region': 'Central America and the Caribbean', 'Country': 'Honduras', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'L', 'Order Date': '8/26/2011', 'Order ID': '938813769', 'Ship Date': '10/7/2011', 'Units Sold': '4712', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '3068501.52', 'Total Cost': '2473611.52', 'Total Profit': '594890.00'}
# topic.costly_order 0
# 502.54
# {'Region': 'Middle East and North Africa', 'Country': 'Somalia', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'M', 'Order Date': '7/15/2010', 'Order ID': '698728597', 'Ship Date': '7/27/2010', 'Units Sold': '8174', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '5462438.98', 'Total Cost': '4107761.96', 'Total Profit': '1354677.02'}
# topic.costly_order 0
# 97.44
# 6.92
# 6.92
# 263.33
# 263.33
# 524.96
# {'Region': 'Europe', 'Country': 'Albania', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'M', 'Order Date': '10/26/2010', 'Order ID': '442557466', 'Ship Date': '11/26/2010', 'Units Sold': '1444', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '940347.24', 'Total Cost': '758042.24', 'Total Profit': '182305.00'}
# topic.costly_order 0
# 31.79
# 56.67
# 364.69
# 263.33
# 56.67
# 6.92
# 97.44
# 35.84
# 364.69
# 90.93
# 56.67
# 524.96
# {'Region': 'Europe', 'Country': 'Monaco', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'L', 'Order Date': '3/14/2013', 'Order ID': '801156365', 'Ship Date': '4/3/2013', 'Units Sold': '8827', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '5748230.67', 'Total Cost': '4633821.92', 'Total Profit': '1114408.75'}
# topic.costly_order 0
# 31.79
# 117.11
# 31.79
# 6.92
# 159.42
# 502.54
# {'Region': 'Central America and the Caribbean', 'Country': 'Antigua and Barbuda ', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'C', 'Order Date': '7/4/2010', 'Order ID': '424520146', 'Ship Date': '7/9/2010', 'Units Sold': '3800', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '2539426.00', 'Total Cost': '1909652.00', 'Total Profit': '629774.00'}
# topic.costly_order 0
# 117.11
# 56.67
# 31.79
# 90.93
# 263.33
# 502.54
# {'Region': 'Asia', 'Country': 'Sri Lanka', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'L', 'Order Date': '10/3/2012', 'Order ID': '591322648', 'Ship Date': '10/19/2012', 'Units Sold': '4367', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '2918335.09', 'Total Cost': '2194592.18', 'Total Profit': '723742.91'}
# topic.costly_order 0
# 117.11
# 90.93
# 56.67
# 56.67
# 364.69
# 97.44
# 90.93
# 35.84
# 364.69
# 159.42
# 97.44
# 263.33
# 6.92
# 6.92
# 6.92
# 263.33
# 159.42
# 56.67
# 502.54
# {'Region': 'Sub-Saharan Africa', 'Country': 'Cameroon', 'Item Type': 'Household', 'Sales Channel': 'Online', 'Order Priority': 'M', 'Order Date': '6/22/2012', 'Order ID': '614848411', 'Ship Date': '6/22/2012', 'Units Sold': '6163', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '4118548.01', 'Total Cost': '3097154.02', 'Total Profit': '1021393.99'}
# topic.costly_order 0
# 31.79
# 159.42
# 90.93
# 364.69
# 35.84
# 524.96
# {'Region': 'Europe', 'Country': 'Monaco', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'L', 'Order Date': '1/2/2016', 'Order ID': '635285556', 'Ship Date': '2/5/2016', 'Units Sold': '3968', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '2584001.28', 'Total Cost': '2083041.28', 'Total Profit': '500960.00'}
# topic.costly_order 0
# 35.84
# 97.44
# 35.84
# 364.69
# 31.79
# 31.79
# 263.33
# 524.96
# {'Region': 'Europe', 'Country': 'Switzerland', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'M', 'Order Date': '5/10/2014', 'Order ID': '115306079', 'Ship Date': '5/15/2014', 'Units Sold': '486', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '316488.06', 'Total Cost': '255130.56', 'Total Profit': '61357.50'}
# topic.costly_order 0
# 263.33
# 117.11
# 90.93
# 364.69
# 35.84
# 90.93
# 90.93
# 97.44
# 35.84
# 159.42
# 524.96
# {'Region': 'Asia', 'Country': 'Uzbekistan', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'L', 'Order Date': '5/31/2010', 'Order ID': '905550515', 'Ship Date': '6/1/2010', 'Units Sold': '1376', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '896064.96', 'Total Cost': '722344.96', 'Total Profit': '173720.00'}
# topic.costly_order 0
# 35.84
# 364.69
# 524.96
# {'Region': 'Europe', 'Country': 'Luxembourg', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'L', 'Order Date': '1/29/2013', 'Order ID': '797727859', 'Ship Date': '2/1/2013', 'Units Sold': '4255', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '2770898.55', 'Total Cost': '2233704.80', 'Total Profit': '537193.75'}
# topic.costly_order 0
# 97.44
# 90.93
# 263.33
# 56.67
# 35.84
# 31.79
# 31.79
# 97.44
# 364.69
# 502.54
# {'Region': 'Europe', 'Country': 'Portugal', 'Item Type': 'Household', 'Sales Channel': 'Online', 'Order Priority': 'M', 'Order Date': '8/30/2014', 'Order ID': '283297336', 'Ship Date': '9/30/2014', 'Units Sold': '2832', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '1892540.64', 'Total Cost': '1423193.28', 'Total Profit': '469347.36'}
# topic.costly_order 0
# 117.11
# 524.96
# {'Region': 'Sub-Saharan Africa', 'Country': 'Central African Republic', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'C', 'Order Date': '4/26/2010', 'Order ID': '571909034', 'Ship Date': '6/8/2010', 'Units Sold': '9447', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '6151980.87', 'Total Cost': '4959297.12', 'Total Profit': '1192683.75'}
# topic.costly_order 0
# 263.33
# 97.44
# 97.44
# 364.69
# 159.42
# 502.54
# {'Region': 'Sub-Saharan Africa', 'Country': 'Senegal', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'M', 'Order Date': '3/16/2010', 'Order ID': '765270984', 'Ship Date': '4/20/2010', 'Units Sold': '9545', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '6378637.15', 'Total Cost': '4796744.30', 'Total Profit': '1581892.85'}
# topic.costly_order 0
# 524.96
# {'Region': 'Europe', 'Country': 'Portugal', 'Item Type': 'Office Supplies', 'Sales Channel': 'Online', 'Order Priority': 'H', 'Order Date': '7/20/2015', 'Order ID': '472011983', 'Ship Date': '8/30/2015', 'Units Sold': '7690', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '5007804.90', 'Total Cost': '4036942.40', 'Total Profit': '970862.50'}
# topic.costly_order 0
# 90.93
# 90.93
# 90.93
# 31.79
# 117.11
# 6.92
# 159.42
# 35.84
# 159.42
# 159.42
# 159.42
# 159.42
# 90.93
# 97.44
# 524.96
# {'Region': 'Middle East and North Africa', 'Country': 'Tunisia ', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'C', 'Order Date': '5/19/2013', 'Order ID': '118183124', 'Ship Date': '5/31/2013', 'Units Sold': '1867', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '1215809.07', 'Total Cost': '980100.32', 'Total Profit': '235708.75'}
# topic.costly_order 0
# 159.42
# 6.92
# 31.79
# 56.67
# 97.44
# 159.42
# 364.69
# 35.84
# 35.84
# 97.44
# 97.44
# 159.42
# 159.42
# 97.44
# 263.33
# 502.54
# {'Region': 'Europe', 'Country': 'Romania', 'Item Type': 'Household', 'Sales Channel': 'Online', 'Order Priority': 'H', 'Order Date': '7/14/2017', 'Order ID': '923048388', 'Ship Date': '8/31/2017', 'Units Sold': '9385', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '6271713.95', 'Total Cost': '4716337.90', 'Total Profit': '1555376.05'}
# topic.costly_order 0
# 97.44
# 524.96
# {'Region': 'Asia', 'Country': 'Tajikistan', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'H', 'Order Date': '11/3/2012', 'Order ID': '659926688', 'Ship Date': '11/16/2012', 'Units Sold': '5827', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '3794600.67', 'Total Cost': '3058941.92', 'Total Profit': '735658.75'}
# topic.costly_order 0
# 56.67
# 31.79
# 364.69
# 502.54
# {'Region': 'Europe', 'Country': 'Latvia', 'Item Type': 'Household', 'Sales Channel': 'Offline', 'Order Priority': 'C', 'Order Date': '12/27/2016', 'Order ID': '876743590', 'Ship Date': '2/10/2017', 'Units Sold': '6766', 'Unit Price': '668.27', 'Unit Cost': '502.54', 'Total Revenue': '4521514.82', 'Total Cost': '3400185.64', 'Total Profit': '1121329.18'}
# topic.costly_order 0
# 524.96
# {'Region': 'Europe', 'Country': 'Italy', 'Item Type': 'Office Supplies', 'Sales Channel': 'Offline', 'Order Priority': 'C', 'Order Date': '11/1/2011', 'Order ID': '361753022', 'Ship Date': '12/19/2011', 'Units Sold': '9613', 'Unit Price': '651.21', 'Unit Cost': '524.96', 'Total Revenue': '6260081.73', 'Total Cost': '5046440.48', 'Total Profit': '1213641.25'}
# topic.costly_order 0
# 31.79
# 117.11
# 97.44
# 97.44
# 159.42
# 97.44
# 117.11
# 117.11
# 90.93
# 117.11
# 35.84
