# %%
from kafka import KafkaAdminClient, KafkaConsumer, KafkaProducer
from kafka.admin import NewTopic
from json import loads
import json
import sys

# Python3 code to remove whitespace 
def remove(string): 
    return string.replace(" ", "") 
      
### Setting up the Python consumer
bootstrap_servers = ['localhost:9092']
topicName = ['test.topic.raw','test.topic.threshold_costs']
consumer = KafkaConsumer (group_id = 'my_group_id3',bootstrap_servers = bootstrap_servers,
auto_offset_reset = 'earliest',value_deserializer=lambda x: loads(x.decode('utf-8'))) ## You can also set it as latest
consumer.subscribe(['test.topic.raw','test.topic.threshold_costs'])


# Required setting for Kafka Producer
                          
topic2 = 'test.topic.'
producer = KafkaProducer(bootstrap_servers = bootstrap_servers)
producer = KafkaProducer()

### Reading the message from consumer
try:
    for message in consumer:
        msg = message.value
        country = str(msg['Country'])
        topic2 = 'test.topic.'
        print(remove(country))
        topic2 += remove(country)
        print(topic2)
        ack = producer.send(topic2,json.dumps(msg).encode('utf-8'))
        metadata = ack.get()
        print(metadata.topic, metadata.partition)
        
except KeyboardInterrupt:
    sys.exit()
# Out:
# Ghana
# test.topic.Ghana
# test.topic.Ghana 0
# Tanzania
# test.topic.Tanzania
# test.topic.Tanzania 0
# Algeria
# test.topic.Algeria
# test.topic.Algeria 0
# Singapore
# test.topic.Singapore
# test.topic.Singapore 0
# PapuaNewGuinea
# test.topic.PapuaNewGuinea
# test.topic.PapuaNewGuinea 0
# Vietnam
# test.topic.Vietnam
# test.topic.Vietnam 0
# Zimbabwe
# test.topic.Zimbabwe
# test.topic.Zimbabwe 0
# France
# test.topic.France
# test.topic.France 0
# TheBahamas
# test.topic.TheBahamas
# test.topic.TheBahamas 0
# Haiti
# test.topic.Haiti
# test.topic.Haiti 0
# Nicaragua
# test.topic.Nicaragua
# test.topic.Nicaragua 0
# Turkmenistan
# test.topic.Turkmenistan
# test.topic.Turkmenistan 0
# China
# test.topic.China
# test.topic.China 0
# Uganda
# test.topic.Uganda
# test.topic.Uganda 0
# Kuwait
# test.topic.Kuwait
# test.topic.Kuwait 0
# UnitedArabEmirates
# test.topic.UnitedArabEmirates
# test.topic.UnitedArabEmirates 0
# Estonia
# test.topic.Estonia
# test.topic.Estonia 0
# India
# test.topic.India
# test.topic.India 0
# Samoa
# test.topic.Samoa
# test.topic.Samoa 0
# CzechRepublic
# test.topic.CzechRepublic
# test.topic.CzechRepublic 0
# Finland
# test.topic.Finland
# test.topic.Finland 0
# Oman
# test.topic.Oman
# test.topic.Oman 0
# Dominica
# test.topic.Dominica
# test.topic.Dominica 0
# Brunei
# test.topic.Brunei
# test.topic.Brunei 0
# SolomonIslands
# test.topic.SolomonIslands
# test.topic.SolomonIslands 0
# Togo
# test.topic.Togo
# test.topic.Togo 0
# Canada
# test.topic.Canada
# test.topic.Canada 0
# Lebanon
# test.topic.Lebanon
# test.topic.Lebanon 0
# SouthKorea
# test.topic.SouthKorea
# test.topic.SouthKorea 0
# Indonesia
# test.topic.Indonesia
# test.topic.Indonesia 0
# AntiguaandBarbuda
# test.topic.AntiguaandBarbuda
# test.topic.AntiguaandBarbuda 0
# Tunisia
# test.topic.Tunisia
# test.topic.Tunisia 0
# Thailand
# test.topic.Thailand
# test.topic.Thailand 0
# Nepal
# test.topic.Nepal
# test.topic.Nepal 0
# Greece
# test.topic.Greece
# test.topic.Greece 0
# Taiwan
# test.topic.Taiwan
# test.topic.Taiwan 0
# Italy
# test.topic.Italy
# test.topic.Italy 0
# Switzerland
# test.topic.Switzerland
# test.topic.Switzerland 0
# Italy
# test.topic.Italy
# test.topic.Italy 0
# Iceland
# test.topic.Iceland
# test.topic.Iceland 0
# Japan
# test.topic.Japan
# test.topic.Japan 0
# Tonga
# test.topic.Tonga
# test.topic.Tonga 0
# Mali
# test.topic.Mali
# test.topic.Mali 0
# Indonesia
# test.topic.Indonesia
# test.topic.Indonesia 0
# Albania
# test.topic.Albania
# test.topic.Albania 0
# Nicaragua
# test.topic.Nicaragua
# test.topic.Nicaragua 0
# Italy
# test.topic.Italy
# test.topic.Italy 0
# Romania
# test.topic.Romania
# test.topic.Romania 0
# Pakistan
# test.topic.Pakistan
# test.topic.Pakistan 0
# DemocraticRepublicoftheCongo
# test.topic.DemocraticRepublicoftheCongo
# test.topic.DemocraticRepublicoftheCongo 0
# Turkmenistan
# test.topic.Turkmenistan
# test.topic.Turkmenistan 0
# Malawi
# test.topic.Malawi
# test.topic.Malawi 0
# Vanuatu
# test.topic.Vanuatu
# test.topic.Vanuatu 0
# Mali
# test.topic.Mali
# test.topic.Mali 0
# DemocraticRepublicoftheCongo
# test.topic.DemocraticRepublicoftheCongo
# test.topic.DemocraticRepublicoftheCongo 0
# EquatorialGuinea
# test.topic.EquatorialGuinea
# test.topic.EquatorialGuinea 0
# UnitedArabEmirates
# test.topic.UnitedArabEmirates
# test.topic.UnitedArabEmirates 0
# ElSalvador
# test.topic.ElSalvador
# test.topic.ElSalvador 0
# Greenland
# test.topic.Greenland
# test.topic.Greenland 0
# Kazakhstan
# test.topic.Kazakhstan
# test.topic.Kazakhstan 0
# Myanmar
# test.topic.Myanmar
# test.topic.Myanmar 0
# Serbia
# test.topic.Serbia
# test.topic.Serbia 0
# Albania
# test.topic.Albania
# test.topic.Albania 0
# Somalia
# test.topic.Somalia
# test.topic.Somalia 0
# Kenya
# test.topic.Kenya
# test.topic.Kenya 0
# Zambia
# test.topic.Zambia
# test.topic.Zambia 0
# Canada
# test.topic.Canada
# test.topic.Canada 0
# MarshallIslands
# test.topic.MarshallIslands
# test.topic.MarshallIslands 0
# Armenia
# test.topic.Armenia
# test.topic.Armenia 0
# Myanmar
# test.topic.Myanmar
# test.topic.Myanmar 0
# TheBahamas
# test.topic.TheBahamas
# test.topic.TheBahamas 0
# Madagascar
# test.topic.Madagascar
# test.topic.Madagascar 0
# Mongolia
# test.topic.Mongolia
# test.topic.Mongolia 0
# Seychelles
# test.topic.Seychelles
# test.topic.Seychelles 0
# SierraLeone
# test.topic.SierraLeone
# test.topic.SierraLeone 0
# CapeVerde
# test.topic.CapeVerde
# test.topic.CapeVerde 0
# Denmark
# test.topic.Denmark
# test.topic.Denmark 0
# SaintKittsandNevis
# test.topic.SaintKittsandNevis
# test.topic.SaintKittsandNevis 0
# Syria
# test.topic.Syria
# test.topic.Syria 0
# SaudiArabia
# test.topic.SaudiArabia
# test.topic.SaudiArabia 0
# Armenia
# test.topic.Armenia
# test.topic.Armenia 0
# Sudan
# test.topic.Sudan
# test.topic.Sudan 0
# Morocco
# test.topic.Morocco
# test.topic.Morocco 0
# Yemen
# test.topic.Yemen
# test.topic.Yemen 0
# Netherlands
# test.topic.Netherlands
# test.topic.Netherlands 0
# Cambodia
# test.topic.Cambodia
# test.topic.Cambodia 0
# EastTimor
# test.topic.EastTimor
# test.topic.EastTimor 0
# Kenya
# test.topic.Kenya
# test.topic.Kenya 0
# SouthKorea
# test.topic.SouthKorea
# test.topic.SouthKorea 0
# CapeVerde
# test.topic.CapeVerde
# test.topic.CapeVerde 0
# CentralAfricanRepublic
# test.topic.CentralAfricanRepublic
# test.topic.CentralAfricanRepublic 0
# Latvia
# test.topic.Latvia
# test.topic.Latvia 0
# ElSalvador
# test.topic.ElSalvador
# test.topic.ElSalvador 0
# Portugal
# test.topic.Portugal
# test.topic.Portugal 0
# Togo
# test.topic.Togo
# test.topic.Togo 0
# Bahrain
# test.topic.Bahrain
# test.topic.Bahrain 0
# Uganda
# test.topic.Uganda
# test.topic.Uganda 0
# Belgium
# test.topic.Belgium
# test.topic.Belgium 0
# Cameroon
# test.topic.Cameroon
# test.topic.Cameroon 0
# Bhutan
# test.topic.Bhutan
# test.topic.Bhutan 0
# Lebanon
# test.topic.Lebanon
# test.topic.Lebanon 0
# Kiribati
# test.topic.Kiribati
# test.topic.Kiribati 0
# Croatia
# test.topic.Croatia
# test.topic.Croatia 0
# Vanuatu
# test.topic.Vanuatu
# test.topic.Vanuatu 0
# Somalia
# test.topic.Somalia
# test.topic.Somalia 0
# SolomonIslands
# test.topic.SolomonIslands
# test.topic.SolomonIslands 0
# Algeria
# test.topic.Algeria
# test.topic.Algeria 0
# Turkey
# test.topic.Turkey
# test.topic.Turkey 0
# Comoros
# test.topic.Comoros
# test.topic.Comoros 0
# Uzbekistan
# test.topic.Uzbekistan
# test.topic.Uzbekistan 0
# DominicanRepublic
# test.topic.DominicanRepublic
# test.topic.DominicanRepublic 0
# Tuvalu
# test.topic.Tuvalu
# test.topic.Tuvalu 0
# Gabon
# test.topic.Gabon
# test.topic.Gabon 0
# Switzerland
# test.topic.Switzerland
# test.topic.Switzerland 0
# Hungary
# test.topic.Hungary
# test.topic.Hungary 0
# Montenegro
# test.topic.Montenegro
# test.topic.Montenegro 0
# PapuaNewGuinea
# test.topic.PapuaNewGuinea
# test.topic.PapuaNewGuinea 0
# Greenland
# test.topic.Greenland
# test.topic.Greenland 0
# Andorra
# test.topic.Andorra
# test.topic.Andorra 0
# Kenya
# test.topic.Kenya
# test.topic.Kenya 0
# Luxembourg
# test.topic.Luxembourg
# test.topic.Luxembourg 0
# Finland
# test.topic.Finland
# test.topic.Finland 0
# Bangladesh
# test.topic.Bangladesh
# test.topic.Bangladesh 0
# SriLanka
# test.topic.SriLanka
# test.topic.SriLanka 0
# Germany
# test.topic.Germany
# test.topic.Germany 0
# Egypt
# test.topic.Egypt
# test.topic.Egypt 0
# Jamaica
# test.topic.Jamaica
# test.topic.Jamaica 0
# Yemen
# test.topic.Yemen
# test.topic.Yemen 0
# Malaysia
# test.topic.Malaysia
# test.topic.Malaysia 0
# Greenland
# test.topic.Greenland
# test.topic.Greenland 0
# Kazakhstan
# test.topic.Kazakhstan
# test.topic.Kazakhstan 0
# Israel
# test.topic.Israel
# test.topic.Israel 0
# Zimbabwe
# test.topic.Zimbabwe
# test.topic.Zimbabwe 0
# VaticanCity
# test.topic.VaticanCity
# test.topic.VaticanCity 0
# Panama
# test.topic.Panama
# test.topic.Panama 0
# Mongolia
# test.topic.Mongolia
# test.topic.Mongolia 0
# NewZealand
# test.topic.NewZealand
# test.topic.NewZealand 0
# Ireland
# test.topic.Ireland
# test.topic.Ireland 0
# TrinidadandTobago
# test.topic.TrinidadandTobago
# test.topic.TrinidadandTobago 0
# Romania
# test.topic.Romania
# test.topic.Romania 0
# SaoTomeandPrincipe
# test.topic.SaoTomeandPrincipe
# test.topic.SaoTomeandPrincipe 0
# Palau
# test.topic.Palau
# test.topic.Palau 0
# Malawi
# test.topic.Malawi
# test.topic.Malawi 0
# Angola
# test.topic.Angola
# test.topic.Angola 0
# Uzbekistan
# test.topic.Uzbekistan
# test.topic.Uzbekistan 0
# Romania
# test.topic.Romania
# test.topic.Romania 0
# Bahrain
# test.topic.Bahrain
# test.topic.Bahrain 0
# CapeVerde
# test.topic.CapeVerde
# test.topic.CapeVerde 0
# Zimbabwe
# test.topic.Zimbabwe
# test.topic.Zimbabwe 0
# CostaRica
# test.topic.CostaRica
# test.topic.CostaRica 0
# Zambia
# test.topic.Zambia
# test.topic.Zambia 0
# Malta
# test.topic.Malta
# test.topic.Malta 0
# Malta
# test.topic.Malta
# test.topic.Malta 0
# Nigeria
# test.topic.Nigeria
# test.topic.Nigeria 0
# Palau
# test.topic.Palau
# test.topic.Palau 0
# Samoa
# test.topic.Samoa
# test.topic.Samoa 0
# CentralAfricanRepublic
# test.topic.CentralAfricanRepublic
# test.topic.CentralAfricanRepublic 0
# Seychelles
# test.topic.Seychelles
# test.topic.Seychelles 0
# Mauritania
# test.topic.Mauritania
# test.topic.Mauritania 0
# Ireland
# test.topic.Ireland
# test.topic.Ireland 0
# SaintVincentandtheGrenadines
# test.topic.SaintVincentandtheGrenadines
# test.topic.SaintVincentandtheGrenadines 0
# Germany
# test.topic.Germany
# test.topic.Germany 0
# Malawi
# test.topic.Malawi
# test.topic.Malawi 0
# Bhutan
# test.topic.Bhutan
# test.topic.Bhutan 0
# SaoTomeandPrincipe
# test.topic.SaoTomeandPrincipe
# test.topic.SaoTomeandPrincipe 0
# PapuaNewGuinea
# test.topic.PapuaNewGuinea
# test.topic.PapuaNewGuinea 0
# Lesotho
# test.topic.Lesotho
# test.topic.Lesotho 0
# Tonga
# test.topic.Tonga
# test.topic.Tonga 0
# Nicaragua
# test.topic.Nicaragua
# test.topic.Nicaragua 0
# Mali
# test.topic.Mali
# test.topic.Mali 0
# China
# test.topic.China
# test.topic.China 0
# Belize
# test.topic.Belize
# test.topic.Belize 0
# SierraLeone
# test.topic.SierraLeone
# test.topic.SierraLeone 0
# Madagascar
# test.topic.Madagascar
# test.topic.Madagascar 0
# Nicaragua
# test.topic.Nicaragua
# test.topic.Nicaragua 0
# Belarus
# test.topic.Belarus
# test.topic.Belarus 0
# BurkinaFaso
# test.topic.BurkinaFaso
# test.topic.BurkinaFaso 0
# Ethiopia
# test.topic.Ethiopia
# test.topic.Ethiopia 0
# Nicaragua
# test.topic.Nicaragua
# test.topic.Nicaragua 0
# Pakistan
# test.topic.Pakistan
# test.topic.Pakistan 0
# Macedonia
# test.topic.Macedonia
# test.topic.Macedonia 0
# Greece
# test.topic.Greece
# test.topic.Greece 0
# Cameroon
# test.topic.Cameroon
# test.topic.Cameroon 0
# Taiwan
# test.topic.Taiwan
# test.topic.Taiwan 0
# Uganda
# test.topic.Uganda
# test.topic.Uganda 0
# Luxembourg
# test.topic.Luxembourg
# test.topic.Luxembourg 0
# SaudiArabia
# test.topic.SaudiArabia
# test.topic.SaudiArabia 0
# Burundi
# test.topic.Burundi
# test.topic.Burundi 0
# Seychelles
# test.topic.Seychelles
# test.topic.Seychelles 0
# EquatorialGuinea
# test.topic.EquatorialGuinea
# test.topic.EquatorialGuinea 0
# Latvia
# test.topic.Latvia
# test.topic.Latvia 0
# Brunei
# test.topic.Brunei
# test.topic.Brunei 0
# Brunei
# test.topic.Brunei
# test.topic.Brunei 0
# Cameroon
# test.topic.Cameroon
# test.topic.Cameroon 0
# Malaysia
# test.topic.Malaysia
# test.topic.Malaysia 0
# Senegal
# test.topic.Senegal
# test.topic.Senegal 0
# Tajikistan
# test.topic.Tajikistan
# test.topic.Tajikistan 0
# CzechRepublic
# test.topic.CzechRepublic
# test.topic.CzechRepublic 0
# SouthSudan
# test.topic.SouthSudan
# test.topic.SouthSudan 0
# Tajikistan
# test.topic.Tajikistan
# test.topic.Tajikistan 0
# Cuba
# test.topic.Cuba
# test.topic.Cuba 0
# Iran
# test.topic.Iran
# test.topic.Iran 0
# DemocraticRepublicoftheCongo
# test.topic.DemocraticRepublicoftheCongo
# test.topic.DemocraticRepublicoftheCongo 0
# Greece
# test.topic.Greece
# test.topic.Greece 0
# India
# test.topic.India
# test.topic.India 0
# Madagascar
# test.topic.Madagascar
# test.topic.Madagascar 0
# Moldova
# test.topic.Moldova
# test.topic.Moldova 0
# Cuba
# test.topic.Cuba
# test.topic.Cuba 0
# Switzerland
# test.topic.Switzerland
# test.topic.Switzerland 0
# AntiguaandBarbuda
# test.topic.AntiguaandBarbuda
# test.topic.AntiguaandBarbuda 0
# SaintKittsandNevis
# test.topic.SaintKittsandNevis
# test.topic.SaintKittsandNevis 0
# Yemen
# test.topic.Yemen
# test.topic.Yemen 0
# MarshallIslands
# test.topic.MarshallIslands
# test.topic.MarshallIslands 0
# Ghana
# test.topic.Ghana
# test.topic.Ghana 0
# Togo
# test.topic.Togo
# test.topic.Togo 0
# Angola
# test.topic.Angola
# test.topic.Angola 0
# Cuba
# test.topic.Cuba
# test.topic.Cuba 0
# Latvia
# test.topic.Latvia
# test.topic.Latvia 0
# Tuvalu
# test.topic.Tuvalu
# test.topic.Tuvalu 0
# Rwanda
# test.topic.Rwanda
# test.topic.Rwanda 0
# Mongolia
# test.topic.Mongolia
# test.topic.Mongolia 0
# Tunisia
# test.topic.Tunisia
# test.topic.Tunisia 0
# Poland
# test.topic.Poland
# test.topic.Poland 0
# Cameroon
# test.topic.Cameroon
# test.topic.Cameroon 0
# Kiribati
# test.topic.Kiribati
# test.topic.Kiribati 0
# Greece
# test.topic.Greece
# test.topic.Greece 0
# Iran
# test.topic.Iran
# test.topic.Iran 0
# Haiti
# test.topic.Haiti
# test.topic.Haiti 0
# Liberia
# test.topic.Liberia
# test.topic.Liberia 0
# Swaziland
# test.topic.Swaziland
# test.topic.Swaziland 0
# Japan
# test.topic.Japan
# test.topic.Japan 0
# Kosovo
# test.topic.Kosovo
# test.topic.Kosovo 0
# Madagascar
# test.topic.Madagascar
# test.topic.Madagascar 0
# Serbia
# test.topic.Serbia
# test.topic.Serbia 0
# Belize
# test.topic.Belize
# test.topic.Belize 0
# Zambia
# test.topic.Zambia
# test.topic.Zambia 0
# Germany
# test.topic.Germany
# test.topic.Germany 0
# Djibouti
# test.topic.Djibouti
# test.topic.Djibouti 0
# EastTimor
# test.topic.EastTimor
# test.topic.EastTimor 0
# CostaRica
# test.topic.CostaRica
# test.topic.CostaRica 0
# Burundi
# test.topic.Burundi
# test.topic.Burundi 0
# Seychelles
# test.topic.Seychelles
# test.topic.Seychelles 0
# Burundi
# test.topic.Burundi
# test.topic.Burundi 0
# Turkey
# test.topic.Turkey
# test.topic.Turkey 0
# Barbados
# test.topic.Barbados
# test.topic.Barbados 0
# India
# test.topic.India
# test.topic.India 0
# Netherlands
# test.topic.Netherlands
# test.topic.Netherlands 0
# Croatia
# test.topic.Croatia
# test.topic.Croatia 0
# Somalia
# test.topic.Somalia
# test.topic.Somalia 0
# TrinidadandTobago
# test.topic.TrinidadandTobago
# test.topic.TrinidadandTobago 0
# Greece
# test.topic.Greece
# test.topic.Greece 0
# Portugal
# test.topic.Portugal
# test.topic.Portugal 0
# Haiti
# test.topic.Haiti
# test.topic.Haiti 0
# Iceland
# test.topic.Iceland
# test.topic.Iceland 0
# TheGambia
# test.topic.TheGambia
# test.topic.TheGambia 0
# Latvia
# test.topic.Latvia
# test.topic.Latvia 0
# Uzbekistan
# test.topic.Uzbekistan
# test.topic.Uzbekistan 0
# Malaysia
# test.topic.Malaysia
# test.topic.Malaysia 0
# Mauritania
# test.topic.Mauritania
# test.topic.Mauritania 0
# Ireland
# test.topic.Ireland
# test.topic.Ireland 0
# Chad
# test.topic.Chad
# test.topic.Chad 0
# India
# test.topic.India
# test.topic.India 0
# Kyrgyzstan
# test.topic.Kyrgyzstan
# test.topic.Kyrgyzstan 0
# Malaysia
# test.topic.Malaysia
# test.topic.Malaysia 0
# Liberia
# test.topic.Liberia
# test.topic.Liberia 0
# BosniaandHerzegovina
# test.topic.BosniaandHerzegovina
# test.topic.BosniaandHerzegovina 0
# Guatemala
# test.topic.Guatemala
# test.topic.Guatemala 0
# Latvia
# test.topic.Latvia
# test.topic.Latvia 0
# Singapore
# test.topic.Singapore
# test.topic.Singapore 0
# Brunei
# test.topic.Brunei
# test.topic.Brunei 0
# MarshallIslands
# test.topic.MarshallIslands
# test.topic.MarshallIslands 0
# Jordan
# test.topic.Jordan
# test.topic.Jordan 0
# Moldova
# test.topic.Moldova
# test.topic.Moldova 0
# Montenegro
# test.topic.Montenegro
# test.topic.Montenegro 0
# Comoros
# test.topic.Comoros
# test.topic.Comoros 0
# Denmark
# test.topic.Denmark
# test.topic.Denmark 0
# Malaysia
# test.topic.Malaysia
# test.topic.Malaysia 0
# Kyrgyzstan
# test.topic.Kyrgyzstan
# test.topic.Kyrgyzstan 0
# Bhutan
# test.topic.Bhutan
# test.topic.Bhutan 0
# Brunei
# test.topic.Brunei
# test.topic.Brunei 0
# TheBahamas
# test.topic.TheBahamas
# test.topic.TheBahamas 0
# Cambodia
# test.topic.Cambodia
# test.topic.Cambodia 0
# Haiti
# test.topic.Haiti
# test.topic.Haiti 0
# Poland
# test.topic.Poland
# test.topic.Poland 0
# Haiti
# test.topic.Haiti
# test.topic.Haiti 0
# Lithuania
# test.topic.Lithuania
# test.topic.Lithuania 0
# Egypt
# test.topic.Egypt
# test.topic.Egypt 0
# Tunisia
# test.topic.Tunisia
# test.topic.Tunisia 0
# SriLanka
# test.topic.SriLanka
# test.topic.SriLanka 0
# Sudan
# test.topic.Sudan
# test.topic.Sudan 0
# Mongolia
# test.topic.Mongolia
# test.topic.Mongolia 0
# Botswana
# test.topic.Botswana
# test.topic.Botswana 0
# Armenia
# test.topic.Armenia
# test.topic.Armenia 0
# Serbia
# test.topic.Serbia
# test.topic.Serbia 0
# Andorra
# test.topic.Andorra
# test.topic.Andorra 0
# Cameroon
# test.topic.Cameroon
# test.topic.Cameroon 0
# Finland
# test.topic.Finland
# test.topic.Finland 0
# Morocco
# test.topic.Morocco
# test.topic.Morocco 0
# Malaysia
# test.topic.Malaysia
# test.topic.Malaysia 0
# Georgia
# test.topic.Georgia
# test.topic.Georgia 0
# Lesotho
# test.topic.Lesotho
# test.topic.Lesotho 0
# Bahrain
# test.topic.Bahrain
# test.topic.Bahrain 0
# NorthKorea
# test.topic.NorthKorea
# test.topic.NorthKorea 0
# CostaRica
# test.topic.CostaRica
# test.topic.CostaRica 0
# Indonesia
# test.topic.Indonesia
# test.topic.Indonesia 0
# Nigeria
# test.topic.Nigeria
# test.topic.Nigeria 0
# Ireland
# test.topic.Ireland
# test.topic.Ireland 0
# PapuaNewGuinea
# test.topic.PapuaNewGuinea
# test.topic.PapuaNewGuinea 0
# CostaRica
# test.topic.CostaRica
# test.topic.CostaRica 0
# Grenada
# test.topic.Grenada
# test.topic.Grenada 0
# Ireland
# test.topic.Ireland
# test.topic.Ireland 0
# Tanzania
# test.topic.Tanzania
# test.topic.Tanzania 0
# Taiwan
# test.topic.Taiwan
# test.topic.Taiwan 0
# Bulgaria
# test.topic.Bulgaria
# test.topic.Bulgaria 0
# Ethiopia
# test.topic.Ethiopia
# test.topic.Ethiopia 0
# Croatia
# test.topic.Croatia
# test.topic.Croatia 0
# Tanzania
# test.topic.Tanzania
# test.topic.Tanzania 0
# Cyprus
# test.topic.Cyprus
# test.topic.Cyprus 0
# Latvia
# test.topic.Latvia
# test.topic.Latvia 0
# Macedonia
# test.topic.Macedonia
# test.topic.Macedonia 0
# Oman
# test.topic.Oman
# test.topic.Oman 0
# Turkmenistan
# test.topic.Turkmenistan
# test.topic.Turkmenistan 0
# Turkey
# test.topic.Turkey
# test.topic.Turkey 0
# Malta
# test.topic.Malta
# test.topic.Malta 0
# Seychelles
# test.topic.Seychelles
# test.topic.Seychelles 0
# EquatorialGuinea
# test.topic.EquatorialGuinea
# test.topic.EquatorialGuinea 0
# Greece
# test.topic.Greece
# test.topic.Greece 0
# Greenland
# test.topic.Greenland
# test.topic.Greenland 0
# Oman
# test.topic.Oman
# test.topic.Oman 0
# Tanzania
# test.topic.Tanzania
# test.topic.Tanzania 0
# Zimbabwe
# test.topic.Zimbabwe
# test.topic.Zimbabwe 0
# Armenia
# test.topic.Armenia
# test.topic.Armenia 0
# Philippines
# test.topic.Philippines
# test.topic.Philippines 0
# Tuvalu
# test.topic.Tuvalu
# test.topic.Tuvalu 0
# Russia
# test.topic.Russia
# test.topic.Russia 0
# SolomonIslands
# test.topic.SolomonIslands
# test.topic.SolomonIslands 0
# Moldova
# test.topic.Moldova
# test.topic.Moldova 0
# Hungary
# test.topic.Hungary
# test.topic.Hungary 0
# Niger
# test.topic.Niger
# test.topic.Niger 0
# Zambia
# test.topic.Zambia
# test.topic.Zambia 0
# TheBahamas
# test.topic.TheBahamas
# test.topic.TheBahamas 0
# NewZealand
# test.topic.NewZealand
# test.topic.NewZealand 0
# Ireland
# test.topic.Ireland
# test.topic.Ireland 0
# VaticanCity
# test.topic.VaticanCity
# test.topic.VaticanCity 0
# UnitedArabEmirates
# test.topic.UnitedArabEmirates
# test.topic.UnitedArabEmirates 0
# Sudan
# test.topic.Sudan
# test.topic.Sudan 0
# MarshallIslands
# test.topic.MarshallIslands
# test.topic.MarshallIslands 0
# Dominica
# test.topic.Dominica
# test.topic.Dominica 0
# Tunisia
# test.topic.Tunisia
# test.topic.Tunisia 0
# Rwanda
# test.topic.Rwanda
# test.topic.Rwanda 0
# Singapore
# test.topic.Singapore
# test.topic.Singapore 0
# Andorra
# test.topic.Andorra
# test.topic.Andorra 0
# Hungary
# test.topic.Hungary
# test.topic.Hungary 0
# Oman
# test.topic.Oman
# test.topic.Oman 0
# Rwanda
# test.topic.Rwanda
# test.topic.Rwanda 0
# Serbia
# test.topic.Serbia
# test.topic.Serbia 0
# Tajikistan
# test.topic.Tajikistan
# test.topic.Tajikistan 0
# SierraLeone
# test.topic.SierraLeone
# test.topic.SierraLeone 0
# Palau
# test.topic.Palau
# test.topic.Palau 0
# Switzerland
# test.topic.Switzerland
# test.topic.Switzerland 0
# Coted'Ivoire
# test.topic.Coted'Ivoire
# ---------------------------------------------------------------------------
# KafkaTimeoutError                         Traceback (most recent call last)
# <ipython-input-2-b830e91ffdb9> in <module>
#      32         topic2 += remove(country)
#      33         print(topic2)
# ---> 34         ack = producer.send(topic2,json.dumps(msg).encode('utf-8'))
#      35         metadata = ack.get()
#      36         print(metadata.topic, metadata.partition)
#
# ~\Anaconda3\lib\site-packages\kafka\producer\kafka.py in send(self, topic, value, key, headers, partition, timestamp_ms)
#     574         key_bytes = value_bytes = None
#     575         try:
# --> 576             self._wait_on_metadata(topic, self.config['max_block_ms'] / 1000.0)
#     577
#     578             key_bytes = self._serialize(
#
# ~\Anaconda3\lib\site-packages\kafka\producer\kafka.py in _wait_on_metadata(self, topic, max_wait)
#     701             if not metadata_event.is_set():
#     702                 raise Errors.KafkaTimeoutError(
# --> 703                     "Failed to update metadata after %.1f secs." % (max_wait,))
#     704             elif topic in self._metadata.unauthorized_topics:
#     705                 raise Errors.TopicAuthorizationFailedError(topic)
#
# KafkaTimeoutError: KafkaTimeoutError: Failed to update metadata after 60.0 secs.
